# %%
### File Handling 

# if example.txt not exist then it will throw an error.
with open('example.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# Hello how are u
# Are you ok
# What is your name
# My name is Krish Kapoor

# %%
# Read a file line by line 

with open('example.txt','r') as file :
    for line in file:
        # print(line , end="")
        print(line.strip())   # strip() Removes the newline character
# Out:
# Hello how are u
# Are you ok
# What is your name
# My name is Krish Kapoor

# %%
# Writing a file(overwriting)

with open('example.txt','w') as file :
    file.write('Hello World \n')
    file.write('This is a new line .')

# %%
# Writing a file (without overwriting)
with open('example.txt' , 'a' ) as file : 
    file.write('\nAppend Operation Takeing place!')

# %%
# Writing a list of line to a file 

lines = ['\nFirst line \n','Second Line \n' , 'Third Line ']

with open('example.txt','a') as file:
    file.writelines(lines)

# %%
## Binary Files

# Writing to a binary file

data = b'\x00\x01\x02\x03\x04'
with open('example.bin' , 'wb') as file:
    file.write(data)

# %%
# Task 
# Read a text file and count the number of lines, words and characters .

def count_text_file(file_path):
    with open(file_path , 'r' ) as file :
        lines =file.readlines()
        line_count = len(lines)
        word_count = sum( len(line.split()) for line in lines)
        char_count = sum( len(line)  for line in lines)
        
        return line_count , word_count , char_count
    
file_path = 'example.txt'
lines , words , characters = count_text_file(file_path)
print(f'Lines : {lines} , Words : {words} , Character : {characters}')
# Out:
# Lines : 3 , Words : 8 , Character : 36

# %%
## Writing and Reading a File  w+ , r+ , a+ etc .

with open('example.txt' , 'w+') as file :
    file.write('Hello World\n')
    file.write('Hello World 2')
    
    # file.seek(0)

    # Read the content of the file 
    content = file.read()
    print(content)
